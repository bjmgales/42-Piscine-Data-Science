# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler


df = pd.read_csv('../../subject/Knights/Train_Knight.csv')

# %%
if 'knight' in df.columns:
    defined_knight = True
    type_save = df['knight']
    df = df.drop('knight', axis=1)
else :
    defined_knight = False

print(df.head(3).to_string(index=False))
scaler = MinMaxScaler()
original_columns = df.columns
df = pd.DataFrame(scaler.fit_transform(df), columns=original_columns)

if defined_knight is True:
    df['knight'] = type_save
    plt.scatter(df[df['knight']=='Jedi']['Awareness'], df[df['knight']=='Jedi']['Stims'],
                color='blue', alpha=0.4, label='Jedi')
    plt.scatter(df[df['knight']=='Sith']['Awareness'], df[df['knight']=='Sith']['Stims'],
                color='red', alpha=0.4, label='Sith')
else:
    plt.scatter(df['Awareness'], df['Stims'],
                color='green', alpha=0.4, label='Knight')
print(df.head(3).to_string(index=False))


plt.xlabel('Awareness')
plt.ylabel('Stims')
plt.legend(loc="upper left")

plt.show()
# Out:
#  Sensitivity  Hability  Strength  Power  Agility  Dexterity  Awareness  Prescience  Reactivity  Midi-chlorien  Slash  Push  Pull  Lightsaber  Survival  Repulse  Friendship  Blocking  Deflection     Mass  Recovery  Evade  Stims  Sprint  Combo  Delay  Attunement  Empowered  Burst  Grasping
#        11.80     17.26     75.26  431.9  0.09087    0.06232    0.02853     0.01638      0.1847        0.06019 0.3438 1.140 2.225       25.06  0.005463  0.01964     0.02079  0.005398     0.01477 0.003071     13.45  24.49  86.00   562.0 0.1244 0.1726      0.1449    0.05356 0.2779   0.08121
#        19.81     22.15    130.00 1260.0  0.09831    0.10270    0.14790     0.09498      0.1582        0.05395 0.7582 1.017 5.865      112.40  0.006494  0.01893     0.03391  0.015210     0.01356 0.001997     27.32  30.88 186.80  2398.0 0.1512 0.3150      0.5372    0.23880 0.2768   0.07615
#        10.97     17.20     71.73  371.5  0.08915    0.11130    0.09457     0.03613      0.1489        0.06640 0.2574 1.376 2.806       18.15  0.008565  0.04638     0.06430  0.017680     0.01516 0.004976     12.36  26.87  90.14   476.4 0.1391 0.4082      0.4779    0.15550 0.2540   0.09532
#  Sensitivity  Hability  Strength    Power  Agility  Dexterity  Awareness  Prescience  Reactivity  Midi-chlorien    Slash     Push     Pull  Lightsaber  Survival  Repulse  Friendship  Blocking  Deflection     Mass  Recovery    Evade    Stims   Sprint    Combo    Delay  Attunement  Empowered    Burst  Grasping knight
#     0.228075  0.255326  0.217469 0.122333 0.339141   0.135019   0.066909    0.089852    0.397475       0.237907 0.083158 0.172339 0.069170    0.033286  0.127477 0.160831    0.052500  0.102254    0.128560 0.075183  0.196371 0.379604 0.177250 0.092607 0.351516 0.140980    0.115735   0.184055 0.365993  0.171652   Sith
#     0.607175  0.420697  0.595743 0.473595 0.439627   0.275247   0.346857    0.521009    0.263636       0.092791 0.233379 0.145156 0.240682    0.196554  0.162525 0.153964    0.085631  0.288123    0.105976 0.038079  0.689790 0.574125 0.679267 0.543846 0.528495 0.279138    0.429073   0.820619 0.362677  0.138463   Jedi
#     0.188793  0.253297  0.193076 0.096713 0.315910   0.305112   0.221787    0.198190    0.216667       0.382326 0.051838 0.224496 0.096546    0.020368  0.232927 0.419468    0.162374  0.334912    0.135839 0.140997  0.157595 0.452055 0.197868 0.071569 0.448590 0.369561    0.381709   0.534364 0.293940  0.264200   Sith
